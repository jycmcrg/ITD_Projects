# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
dengue = pd.read_csv('datasets\\dengue.csv')
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %% [markdown]
# <h1>Check Null</h1>

# %%
dengue.isnull().sum()
# Out:
# Month            0
# Year             0
# Region           0
# Dengue_Cases     0
# Dengue_Deaths    0
# dtype: int64

# %%
dengue.dtypes
# Out:
# Month            object
# Year              int64
# Region           object
# Dengue_Cases      int64
# Dengue_Deaths     int64
# dtype: object

# %% [markdown]
# <h1>Change to Category</h1>

# %%
dengue['Month'] = dengue['Month'].astype('category')
dengue['Region'] = dengue['Region'].astype('category')

dengue.dtypes
# Out:
# Month            category
# Year                int64
# Region           category
# Dengue_Cases        int64
# Dengue_Deaths       int64
# dtype: object

# %% [markdown]
# <h1 style=background-color:yellow>Q1. Which Region have the Highest total dengue cases?</h1>
# <h2>Insight #1: <b>REGION IV-A</b> have the highest total dengue cases in Region.</h2>
# <h1 style=background-color:yellow>Q2. Which Region have the Lowest total dengue cases?</h1>
# <h2>Insight #2: <b>BARMM</b> have the lowest total dengue cases in Region.</h2>

# %%
region_cases = dengue.groupby(["Region"])['Dengue_Cases'].sum().reset_index()
region_cases
# Out:
#          Region  Dengue_Cases
# 0         BARMM         11537
# 1           CAR         30582
# 2           NCR        115966
# 3      Region I         59066
# 4     Region II         45141
# 5    Region III        131064
# 6   Region IV-A        163029
# 7   Region IV-B         30849
# 8     Region IX         47781
# 9      Region V         22167
# 10    Region VI        117523
# 11   Region VII        110683
# 12  Region VIII         51983
# 13     Region X         82437
# 14    Region XI         32522
# 15   Region XII         59802
# 16  Region XIII         35293

# %%
region_cases = dengue.groupby(["Region"])['Dengue_Cases'].sum().reset_index()
sns.barplot(data=region_cases, x="Dengue_Cases", y="Region")
plt.title('REGION that have the HIGHEST and LOWEST Total Dengue Cases')
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q3. Which Month had the highest number of dengue cases?</h1>
# <h2>Insight #3: <b>AUGUST</b> had the highest number of dengue cases.</h2>
# <h1 style=background-color:yellow>Q4. Which Month had the lowest number of dengue cases?</h1>
# <h2>Insight #4: <b>MAY</b> had the lowest number of dengue cases.</h2>

# %%
month_cases = dengue.groupby(["Month"])['Dengue_Cases'].sum().reset_index()
month_cases
# Out:
#         Month  Dengue_Cases
# 0       April         32508
# 1      August        187554
# 2    December         88431
# 3    February         77801
# 4     January         84328
# 5        July        138242
# 6        June         58110
# 7       March         57576
# 8         May         32387
# 9    November         94900
# 10    October        117645
# 11  September        177943

# %%
region_cases = dengue.groupby(["Month"])['Dengue_Cases'].sum().reset_index()
sns.barplot(data=region_cases, x="Dengue_Cases", y="Month")
plt.title('MONTH that have the HIGHEST and LOWEST Total Dengue Cases')
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q5. What is the total number of dengue cases recorded?</h1>
# <h2>Insight #5: The total number of dengue cases recorded is <b>1147425</b>.</h2>

# %%
total_cases = dengue['Dengue_Cases'].sum()
total_cases
# Out:
# 1147425

# %% [markdown]
# <h1 style=background-color:yellow>Q6. What is the total number of dengue death recorded?</h1>
# <h2>Insight #6: The total number of dengue deaths recorded is <b>16844</b>.</h2>

# %%
total_deaths = dengue['Dengue_Deaths'].sum()
total_deaths
# Out:
# 16844

# %% [markdown]
# <h1 style=background-color:yellow>Q7. Is there correlation between dengue cases and dengue deaths?</h1>
# <h2>Insight #7: There is <b>NO CORRELATION</b> between Dengue Cases and Dengue Deaths.</h2>

# %%
dengue['Dengue_Cases'].corr(dengue['Dengue_Deaths'])
# Out:
# 0.03832213720419488

# %%
plt.scatter(dengue['Dengue_Cases'], dengue['Dengue_Deaths'])
plt.title('CORRELATION between Dengue Cases and Dengue Deaths')
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q8. Which Year had the highest number of dengue cases? </h1>
# <h2>Insight #8: Year <b>2019</b> had the Highest number of Dengue Cases.</h2>
# <h1 style=background-color:yellow>Q9. Which year had the lowest number of dengue cases?</h1>
# <h2>Insight #9: Year <b>2020</b> had the Lowest number of Dengue Cases.</h2>

# %%
year_cases = dengue.groupby(["Year"])['Dengue_Cases'].sum().reset_index()
year_cases
# Out:
#    Year  Dengue_Cases
# 0  2016        209544
# 1  2017        154155
# 2  2018        250783
# 3  2019        441902
# 4  2020         91041

# %%
year_cases = dengue.groupby(["Year"])['Dengue_Cases'].sum().reset_index()
sns.barplot(data=year_cases, x="Year", y="Dengue_Cases")
plt.title('YEAR that have the HIGHEST and LOWEST Total Dengue Cases')
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q10. Which month had the highest average number of dengue deaths?</h1>
# <h2>Insight #10: The Month with the Highest Average number of Dengue Deaths is <b>OCTOBER</b> with the average of <b>78.5</b>.</h2>
# <h1 style=background-color:yellow>Q11. Which month had the lowest average number of dengue deaths?</h1>
# <h2>Insight #11: The Month with the Lowest Average number of Dengue Deaths is <b>MAY</b> with the average of <b>1.9</b>.</h2>

# %%
month_dengue = np.round(dengue.groupby(["Month"])['Dengue_Deaths'].mean(), 1).reset_index()
month_dengue
# Out:
#         Month  Dengue_Deaths
# 0       April            2.4
# 1      August            8.4
# 2    December            4.8
# 3    February            3.7
# 4     January            4.6
# 5        July            7.2
# 6        June            3.8
# 7       March            3.4
# 8         May            1.9
# 9    November            7.2
# 10    October           78.5
# 11  September           72.3

# %%
month_dengue = dengue.groupby(["Month"])['Dengue_Deaths'].mean().reset_index()
sns.barplot(data=month_dengue, x="Month", y="Dengue_Deaths")
plt.title('MONTH that have the HIGHEST and LOWEST Total Dengue Deaths')
plt.gcf().set_size_inches(15, 6)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q12. Which Year had the highest average number of dengue deaths?</h1>
# <h2>Insight #12: The Year with the Highest Average number of Dengue Deaths is <b>2016</b> with the average of <b>39.8</b>.</h2>
# <h1 style=background-color:yellow>Q13. Which Year had the lowest average number of dengue deaths?</h1>
# <h2>Insight #13: The Year with the Lowest Average number of Dengue Deaths is <b>2020</b> with the average of <b>5.9</b>.</h2>

# %%
year_dengue = np.round(dengue.groupby(["Year"])['Dengue_Deaths'].mean(), 1).reset_index()
year_dengue
# Out:
#    Year  Dengue_Deaths
# 0  2016           39.8
# 1  2017           22.4
# 2  2018            6.0
# 3  2019            8.5
# 4  2020            5.9

# %%
year_dengue = dengue.groupby(["Year"])['Dengue_Deaths'].mean().reset_index()
sns.barplot(data=year_dengue, x="Year", y="Dengue_Deaths")
plt.title('YEAR that have the HIGHEST and LOWEST Total Dengue Deaths')
plt.gcf().set_size_inches(15, 6)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q14. Which Region had the highest average number of dengue deaths?</h1>
# <h2>Insight #14: The Region with the Highest Average number of Dengue Deaths is <b>NCR</b> with the average of <b>66.8</b>.</h2>
# <h1 style=background-color:yellow>Q15. Which Region had the lowest average number of dengue deaths?</h1>
# <h2>Insight #15: The Region with the Highest Average number of Dengue Deaths is <b>REGION IV-B</b> with the average of <b>2.2</b>.</h2>

# %%
region_dengue = np.round(dengue.groupby(["Region"])['Dengue_Deaths'].mean(), 1).reset_index()
region_dengue
# Out:
#          Region  Dengue_Deaths
# 0         BARMM            5.5
# 1           CAR           16.8
# 2           NCR           66.8
# 3      Region I            2.6
# 4     Region II            3.2
# 5    Region III            8.0
# 6   Region IV-A           10.9
# 7   Region IV-B            2.2
# 8     Region IX            8.9
# 9      Region V            3.1
# 10    Region VI           30.4
# 11   Region VII           29.3
# 12  Region VIII            9.8
# 13     Region X           14.1
# 14    Region XI            6.4
# 15   Region XII           46.6
# 16  Region XIII           16.1

# %%
region_dengue = dengue.groupby(["Region"])['Dengue_Deaths'].mean().reset_index()
sns.barplot(data=region_dengue, x="Region", y="Dengue_Deaths")
plt.title('REGION that have the HIGHEST and LOWEST Total Dengue Deaths')
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q16. Do the Denge Deaths consistently peak in the same months every year?</h1>
# <h2>Insight #16: The year <b>2016 and 2017</b> shows a increase in dengue deaths around <b>SEPTEMBER TO OCTOBER</b>
# with 2016 peaking at nearly 4000 deaths.</h2>

# %%
month_year_deaths = dengue.groupby(["Year", "Month"])["Dengue_Deaths"].sum().reset_index()
month_year_deaths
# Out:
#     Year      Month  Dengue_Deaths
# 0   2016      April             40
# 1   2016     August            132
# 2   2016   December             83
# 3   2016   February             43
# 4   2016    January             73
# 5   2016       July            123
# 6   2016       June             69
# 7   2016      March             47
# 8   2016        May             41
# 9   2016   November            104
# 10  2016    October           3954
# 11  2016  September           3418
# 12  2017      April             43
# 13  2017     August            111
# 14  2017   December             73
# 15  2017   February             64
# 16  2017    January             95
# 17  2017       July             74
# 18  2017       June             42
# 19  2017      March             36
# 20  2017        May             23
# 21  2017   November             78
# 22  2017    October           2098
# 23  2017  September           1826
# 24  2018      April             41
# 25  2018     August            156
# ...

# %%
sns.lineplot(data=month_year_deaths, x="Month", y="Dengue_Deaths", hue="Year", marker="o")
plt.gcf().set_size_inches(15, 6)

# %% [markdown]
# <h1 style=background-color:yellow>Q17. Which Month had the Highest Number of Dengue Deaths in 2016?</h1>
# <h2>Insight #17: The Highest number of Dengue Deaths in 2016 is the month of <b>OCTOBER</b>. While <b>APRIL</b> has the lowest number of dengue deaths in 2016.</h2>

# %%
dengue_2016 = dengue[dengue['Year'] == 2016]
dengue_2016
# Out:
#          Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0      January  2016  Region I           705              1
# 1     February  2016  Region I           374              0
# 2        March  2016  Region I           276              0
# 3        April  2016  Region I           240              2
# 4          May  2016  Region I           243              1
# ..         ...   ...       ...           ...            ...
# 967     August  2016     BARMM           327              2
# 968  September  2016     BARMM           124            105
# 969    October  2016     BARMM            82            109
# 970   November  2016     BARMM           143              1
# 971   December  2016     BARMM           162              2
#
# [204 rows x 5 columns]

# %%
monthly_deaths_2016 = dengue_2016.groupby('Month')['Dengue_Deaths'].sum()
monthly_deaths_2016
# Out:
# Month
# January        73
# February       43
# March          47
# April          40
# May            41
# June           69
# July          123
# August        132
# September    3418
# October      3954
# November      104
# December       83
# Name: Dengue_Deaths, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_deaths_2016 = monthly_deaths_2016.reindex(month_order)
sns.barplot(x=monthly_deaths_2016.index, y=monthly_deaths_2016.values)
plt.title('Dengue Deaths in 2016')
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q18. Which Month had the Highest Number of Dengue Deaths in 2017?</h1>
# <h2>Insight #18: The Highest number of Dengue Deaths in 2017 is the month of <b>OCTOBER</b>. While <b>MAY</b> has the lowest number of dengue deaths in 2017.</h2>

# %%
dengue_2017 = dengue[dengue['Year'] == 2017]
dengue_2017
# Out:
#          Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 12     January  2017  Region I           285              0
# 13    February  2017  Region I           202              2
# 14       March  2017  Region I           151              1
# 15       April  2017  Region I           174              1
# 16         May  2017  Region I           179              0
# ..         ...   ...       ...           ...            ...
# 979     August  2017     BARMM            41              0
# 980  September  2017     BARMM            33              1
# 981    October  2017     BARMM            38              0
# 982   November  2017     BARMM            17              0
# 983   December  2017     BARMM            21              0
#
# [204 rows x 5 columns]

# %%
monthly_deaths_2017 = dengue_2017.groupby('Month')['Dengue_Deaths'].sum()
monthly_deaths_2017
# Out:
# Month
# January        95
# February       64
# March          36
# April          43
# May            23
# June           42
# July           74
# August        111
# September    1826
# October      2098
# November       78
# December       73
# Name: Dengue_Deaths, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_deaths_2017 = monthly_deaths_2017.reindex(month_order)
sns.barplot(x=monthly_deaths_2017.index, y=monthly_deaths_2017.values)
plt.title('Dengue Deaths in 2017')
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q19. Which Month had the Highest Number of Dengue Deaths in 2018?</h1>
# <h2>Insight #19: The Highest number of Dengue Deaths in 2018 is the month of <b>SEPTEMBER</b>. While <b>MAY</b> has the lowest number of dengue deaths in 2018.</h2>

# %%
dengue_2018 = dengue[dengue['Year'] == 2018]
dengue_2018
# Out:
#          Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 24     January  2018  Region I           699              6
# 25    February  2018  Region I           448              3
# 26       March  2018  Region I           235              1
# 27       April  2018  Region I           325              0
# 28         May  2018  Region I           334              0
# ..         ...   ...       ...           ...            ...
# 991     August  2018     BARMM           253              2
# 992  September  2018     BARMM           261              0
# 993    October  2018     BARMM           246              8
# 994   November  2018     BARMM           183              4
# 995   December  2018     BARMM           208              2
#
# [204 rows x 5 columns]

# %%
monthly_deaths_2018 = dengue_2018.groupby('Month')['Dengue_Deaths'].sum()
monthly_deaths_2018
# Out:
# Month
# January       65
# February      43
# March         58
# April         41
# May           31
# June          78
# July         153
# August       156
# September    185
# October      150
# November     131
# December     135
# Name: Dengue_Deaths, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_deaths_2018 = monthly_deaths_2018.reindex(month_order)
sns.barplot(x=monthly_deaths_2018.index, y=monthly_deaths_2018.values)
plt.title('Dengue Deaths in 2018')
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q20. Which Month had the Highest Number of Dengue Deaths in 2019?</h1>
# <h2>Insight #20: The Highest number of Dengue Deaths in 2019 is the month of <b>SEPTEMBER</b>. While <b>MAY</b> has the lowest number of dengue deaths in 2019.</h2>

# %%
dengue_2019 = dengue[dengue['Year'] == 2019]
dengue_2019
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 36      January  2019  Region I           596              2
# 37     February  2019  Region I           633              1
# 38        March  2019  Region I           399              0
# 39        April  2019  Region I           183              1
# 40          May  2019  Region I           197              1
# ...         ...   ...       ...           ...            ...
# 1003     August  2019     BARMM           811              6
# 1004  September  2019     BARMM           807              2
# 1005    October  2019     BARMM           481              2
# 1006   November  2019     BARMM           362              0
# 1007   December  2019     BARMM           288              3
#
# [204 rows x 5 columns]

# %%
monthly_deaths_2019 = dengue_2019.groupby('Month')['Dengue_Deaths'].sum()
monthly_deaths_2019
# Out:
# Month
# April         59
# August       280
# December      91
# February     101
# January       94
# July         232
# June         119
# March        103
# May           56
# November      88
# October      133
# September    377
# Name: Dengue_Deaths, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_deaths_2019 = monthly_deaths_2019.reindex(month_order)
sns.barplot(x=monthly_deaths_2019.index, y=monthly_deaths_2019.values)
plt.title('Dengue Deaths in 2019')
plt.gcf().set_size_inches(20, 8)
plt.show()

# %% [markdown]
# <h1 style=background-color:yellow>Q21. Which Month had the Highest Number of Dengue Deaths in 2020?</h1>
# <h2>Insight #21: The Highest number of Dengue Deaths in 2020 is the month of <b>SEPTEMBER</b>. While <b>MAY</b> has the lowest number of dengue deaths in 2020.</h2>

# %%
dengue_2020 = dengue[dengue['Year'] == 2020]
dengue_2020
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 48      January  2020  Region I           424              1
# 49     February  2020  Region I           442              2
# 50        March  2020  Region I           352              5
# 51        April  2020  Region I            46              2
# 52          May  2020  Region I            87              0
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [204 rows x 5 columns]

# %%
monthly_deaths_2020 = dengue_2020.groupby('Month')['Dengue_Deaths'].sum()
monthly_deaths_2020
# Out:
# Month
# January       67
# February      64
# March         47
# April         17
# May           11
# June          14
# July          29
# August        35
# September    342
# October      335
# November     212
# December      22
# Name: Dengue_Deaths, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_deaths_2020 = monthly_deaths_2020.reindex(month_order)
sns.barplot(x=monthly_deaths_2020.index, y=monthly_deaths_2020.values)
plt.title('Dengue Deaths in 2020')
plt.gcf().set_size_inches(20, 8)
plt.show()
